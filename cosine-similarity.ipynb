# %%
# %pip install scikit-learn pandas
# Out:
# Requirement already satisfied: scikit-learn in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: pandas in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/diptobiswas/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import IPython.display as ipd
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing

file_path = 'data'

# Read data
data = pd.read_csv(f'{file_path}/features_30_sec.csv', index_col='filename')

# Extract labels
labels = data[['label']]

# Drop labels from original dataframe
data = data.drop(columns=['length','label'])

# Scale the data
data_scaled=preprocessing.scale(data)
print('Scaled data type:', type(data_scaled))
# Out:
# Scaled data type: <class 'numpy.ndarray'>

# %%
# Cosine similarity
similarity = cosine_similarity(data_scaled)
print("Similarity shape:", similarity.shape)

# Convert into a dataframe and then set the row index and column names as labels
sim_df_labels = pd.DataFrame(similarity)
sim_df_names = sim_df_labels.set_index(labels.index)
sim_df_names.columns = labels.index

sim_df_names.head()
# Out:
# Similarity shape: (1000, 1000)
# filename         blues.00000.wav  blues.00001.wav  blues.00002.wav  \
# filename
# blues.00000.wav         1.000000         0.049231         0.589618
# blues.00001.wav         0.049231         1.000000        -0.096834
# blues.00002.wav         0.589618        -0.096834         1.000000
# blues.00003.wav         0.284862         0.520903         0.210411
# blues.00004.wav         0.025561         0.080749         0.400266
#
# filename         blues.00003.wav  blues.00004.wav  blues.00005.wav  \
# filename
# blues.00000.wav         0.284862         0.025561        -0.346688
# blues.00001.wav         0.520903         0.080749         0.307856
# blues.00002.wav         0.210411         0.400266        -0.082019
# blues.00003.wav         1.000000         0.126437         0.134796
# blues.00004.wav         0.126437         1.000000         0.556066
#
# filename         blues.00006.wav  blues.00007.wav  blues.00008.wav  \
# filename
# blues.00000.wav        -0.219483        -0.167626         0.641877
# blues.00001.wav         0.318286         0.415258         0.120649
# blues.00002.wav        -0.028061         0.104446         0.468113
# blues.00003.wav         0.300746         0.324566         0.352758
# blues.00004.wav         0.482195         0.623455         0.029703
#
# filename         blues.00009.wav  ...  rock.00090.wav  rock.00091.wav  \
# filename                          ...
# blues.00000.wav        -0.097889  ...       -0.082829        0.546169
# blues.00001.wav         0.404168  ...       -0.098111       -0.325126
# blues.00002.wav        -0.132532  ...       -0.032408        0.561074
# blues.00003.wav         0.295184  ...       -0.320107       -0.206516
# blues.00004.wav         0.471657  ...        0.087605        0.017366
#
# filename         rock.00092.wav  rock.00093.wav  rock.00094.wav  \
# filename
# blues.00000.wav        0.578558        0.662590        0.571629
# blues.00001.wav       -0.370792       -0.191698       -0.330834
# blues.00002.wav        0.590779        0.583293        0.514537
# blues.00003.wav       -0.151132        0.041986       -0.172515
# blues.00004.wav        0.138035        0.104684       -0.034594
#
# filename         rock.00095.wav  rock.00096.wav  rock.00097.wav  \
# filename
# blues.00000.wav        0.610942        0.640835        0.496294
# blues.00001.wav       -0.077301       -0.222119       -0.302573
# blues.00002.wav        0.495707        0.566837        0.589983
# blues.00003.wav       -0.000287        0.020515       -0.107821
# blues.00004.wav        0.063454        0.063546        0.172944
#
# filename         rock.00098.wav  rock.00099.wav
# filename
# blues.00000.wav        0.284958        0.304098
# blues.00001.wav        0.499562        0.311723
# blues.00002.wav        0.216378        0.321069
# blues.00003.wav        0.502279        0.183210
# blues.00004.wav        0.153192        0.061785
#
# [5 rows x 1000 columns]

# %%
def recommender(name):
    series = sim_df_names[name].sort_values(ascending = False)
    
    # Remove cosine similarity == 1 (songs will always have the best match with themselves)
    series = series.drop(name)
    topfive = series.head(5)
    songnames = topfive.index.tolist()
    address_list = ['data/blues',
                   'data/classical',
                   'data/country',
                   'data/disco',
                   'data/hiphop',
                   'data/jazz',
                   'data/metal',
                   'data/pop',
                   'data/reggae',
                   'data/rock']
    genre_list = ["blues", "classical", "country", "disco", 
                  "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
    songlist = []
    songnames = []
    for songname in topfive.index:
        songgenre = songname.split('.')[0]
        address = genre_list.index(songgenre)
        fileaddress = address_list[address] + ('/') + songname
        songlist.append(fileaddress)
        songnames.append(songname)
    return songlist, songnames

# %%
now_playing = 'hiphop.00010.wav'
playlist, songname = recommender(now_playing)
print('Now playing:', now_playing)
ipd.Audio('data/hiphop/hiphop.00010.wav')
# Out:
# Now playing: hiphop.00010.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#print('Recommended songs:\n\n', pd.Series(songname))
print(playlist[0])
ipd.Audio(playlist[0])
# Out:
# data/hiphop/hiphop.00017.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
